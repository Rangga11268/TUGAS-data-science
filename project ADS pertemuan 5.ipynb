# %%
import pandas as pd
data=pd.read_csv("creditapproval-testing.csv")

# %%
data.head(5)
# Out:
#   nama_nasabah jenis_kelamin  umur  jml_pinjaman  jkw  jml_angsuran_per_bulan  \
# 0         x767             P    36     439000.01    6                95300.01
# 1         x768             P    42     783333.34    9                95370.37
# 2         x769             P    34    5000000.00   24               245833.41
# 3         x770             L    32    1000000.00   12                90833.37
# 4         x771             P    34    2000000.00   12               181666.74
#
#    type_pinjaman  jenis_pinjaman  bi_sektor_ekonomi  col  bi_golongan_debitur  \
# 0            100             301               6000    2                  874
# 1            100             301               6000    2                  874
# 2            100             301               6000    2                  874
# 3            100             301               6000    2                  874
# 4            100             301               6000    2                  874
#
# ...

# %%
data.tail(5)
# Out:
#    nama_nasabah jenis_kelamin  umur  jml_pinjaman  jkw  \
# 95         x862             P    22     5000000.0   12
# 96         x863             P    35     1000000.0   60
# 97         x864             P    29     1000000.0   12
# 98         x865             P    36      500000.0    8
# 99         x866             P    31     1000000.0   60
#
#     jml_angsuran_per_bulan  type_pinjaman  jenis_pinjaman  bi_sektor_ekonomi  \
# 95               566666.74            100             301               6000
# 96                18167.06            100             301               6000
# 97                90761.37            100             301               6000
# 98                67452.00            100             301               6000
# 99                18167.06            100             301               6000
#
#     col  bi_golongan_debitur  bi_gol_penjamin  saldo_nominatif  \
# 95    1                  874                0       5000000.00
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   nama_nasabah            100 non-null    object
#  1   jenis_kelamin           100 non-null    object
#  2   umur                    100 non-null    int64
#  3   jml_pinjaman            100 non-null    float64
#  4   jkw                     100 non-null    int64
#  5   jml_angsuran_per_bulan  100 non-null    float64
#  6   type_pinjaman           100 non-null    int64
#  7   jenis_pinjaman          100 non-null    int64
#  8   bi_sektor_ekonomi       100 non-null    int64
#  9   col                     100 non-null    int64
#  10  bi_golongan_debitur     100 non-null    int64
#  11  bi_gol_penjamin         100 non-null    int64
#  12  saldo_nominatif         100 non-null    float64
#  13  tunggakan_pokok         100 non-null    float64
# ...

# %%
data.nunique()
# Out:
# nama_nasabah              100
# jenis_kelamin               2
# umur                       33
# jml_pinjaman               33
# jkw                        20
# jml_angsuran_per_bulan     61
# type_pinjaman               1
# jenis_pinjaman              5
# bi_sektor_ekonomi           2
# col                         4
# bi_golongan_debitur         2
# bi_gol_penjamin             4
# saldo_nominatif            70
# tunggakan_pokok            57
# tunggakan_bunga            27
# status kredit               2
# dtype: int64

# %%
data.isnull()
# Out:
#     nama_nasabah  jenis_kelamin   umur  jml_pinjaman    jkw  \
# 0          False          False  False         False  False
# 1          False          False  False         False  False
# 2          False          False  False         False  False
# 3          False          False  False         False  False
# 4          False          False  False         False  False
# ..           ...            ...    ...           ...    ...
# 95         False          False  False         False  False
# 96         False          False  False         False  False
# 97         False          False  False         False  False
# 98         False          False  False         False  False
# 99         False          False  False         False  False
#
#     jml_angsuran_per_bulan  type_pinjaman  jenis_pinjaman  bi_sektor_ekonomi  \
# 0                    False          False           False              False
# 1                    False          False           False              False
# ...

# %%
data.isnull().sum()
# Out:
# nama_nasabah              0
# jenis_kelamin             0
# umur                      0
# jml_pinjaman              0
# jkw                       0
# jml_angsuran_per_bulan    0
# type_pinjaman             0
# jenis_pinjaman            0
# bi_sektor_ekonomi         0
# col                       0
# bi_golongan_debitur       0
# bi_gol_penjamin           0
# saldo_nominatif           0
# tunggakan_pokok           0
# tunggakan_bunga           0
# status kredit             0
# dtype: int64

# %%
data = data.drop(['col'], axis = 1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   nama_nasabah            100 non-null    object
#  1   jenis_kelamin           100 non-null    object
#  2   umur                    100 non-null    int64
#  3   jml_pinjaman            100 non-null    float64
#  4   jkw                     100 non-null    int64
#  5   jml_angsuran_per_bulan  100 non-null    float64
#  6   type_pinjaman           100 non-null    int64
#  7   jenis_pinjaman          100 non-null    int64
#  8   bi_sektor_ekonomi       100 non-null    int64
#  9   bi_golongan_debitur     100 non-null    int64
#  10  bi_gol_penjamin         100 non-null    int64
#  11  saldo_nominatif         100 non-null    float64
#  12  tunggakan_pokok         100 non-null    float64
#  13  tunggakan_bunga         100 non-null    float64
# ...

# %%
import numpy as np

np.random.seed(0)
data['tanggal_pinjam'] = pd.to_datetime(
    np.random.choice(pd.date_range('2022-01-01', '2023-12-31'), size=len(data))
)
data['tahun_pinjam'] = data['tanggal_pinjam'].dt.year
data.head()
# Out:
#   nama_nasabah jenis_kelamin  umur  jml_pinjaman  jkw  jml_angsuran_per_bulan  \
# 0         x767             P    36     439000.01    6                95300.01
# 1         x768             P    42     783333.34    9                95370.37
# 2         x769             P    34    5000000.00   24               245833.41
# 3         x770             L    32    1000000.00   12                90833.37
# 4         x771             P    34    2000000.00   12               181666.74
#
#    type_pinjaman  jenis_pinjaman  bi_sektor_ekonomi  bi_golongan_debitur  \
# 0            100             301               6000                  874
# 1            100             301               6000                  874
# 2            100             301               6000                  874
# 3            100             301               6000                  874
# 4            100             301               6000                  874
#
# ...

# %%
data['Gender'] = data['jenis_kelamin'].str.split().str.get(0)
data['Detail'] = (
    data['jenis_kelamin'].str.split().str.get(1).fillna(' ') + " " +
    data['jenis_kelamin'].str.split().str.get(2).fillna(' ')
).str.strip()
print(data[['jenis_kelamin', 'Gender', 'Detail']].head())
# Out:
#   jenis_kelamin Gender Detail
# 0             P      P
# 1             P      P
# 2             P      P
# 3             L      L
# 4             P      P

# %%
print(data.umur.unique())
print(data.umur.nunique())
# Out:
# [ 36  42  34  32  30  44  31  48  45   2 -43  41  52  28  12  37  29  46
#   35  40  27  43  39  33  51  26  25  49  38  60  50  47  22]
# 33

# %%
searchfor = ['-43']
data[data.umur.astype(str).str.contains('|'.join(searchfor))].head(1)
# Out:
#    nama_nasabah jenis_kelamin  umur  jml_pinjaman  jkw  \
# 12         x779             P   -43      275000.0    8
#
#     jml_angsuran_per_bulan  type_pinjaman  jenis_pinjaman  bi_sektor_ekonomi  \
# 12                 20000.0            100             303               6000
#
#     bi_golongan_debitur  bi_gol_penjamin  saldo_nominatif  tunggakan_pokok  \
# 12                  874                0         160000.0         160000.0
#
#     tunggakan_bunga status kredit tanggal_pinjam  tahun_pinjam Gender Detail
# 12              0.0         MACET     2023-08-24          2023      P

# %%
data['umur'] = pd.to_numeric(data['umur'], errors='coerce')
data['umur'] = data['umur'].replace(-43, 43)

# %%
searchfor = ['43']
data[data.umur.astype(str).str.contains('|'.join(searchfor))].head(1)
# Out:
#    nama_nasabah jenis_kelamin  umur  jml_pinjaman  jkw  \
# 12         x779             P    43      275000.0    8
#
#     jml_angsuran_per_bulan  type_pinjaman  jenis_pinjaman  bi_sektor_ekonomi  \
# 12                 20000.0            100             303               6000
#
#     bi_golongan_debitur  bi_gol_penjamin  saldo_nominatif  tunggakan_pokok  \
# 12                  874                0         160000.0         160000.0
#
#     tunggakan_bunga status kredit tanggal_pinjam  tahun_pinjam Gender Detail
# 12              0.0         MACET     2023-08-24          2023      P

# %%
import matplotlib.pyplot as pit
data.plot(kind='scatter', x='umur', y='tunggakan_pokok', color='orange')
pit.xlabel('Umur')
pit.ylabel('Tunggakan Pokok')
pit.title('Scatter Plot Umur vs Tunggakan Pokok')
pit.show()

# %%
data['umur'].plot(kind='hist', bins=15, color='lightgreen', edgecolor='black')
pit.xlabel('Umur')
pit.ylabel('Frekuensi')
pit.title('Distribusi Umur Nasabah')
pit.show()

# %%
data['jml_pinjaman'].plot(kind='hist', bins=20, color='skyblue', edgecolor='black')
pit.xlabel('Jumlah Pinjaman')
pit.ylabel('Frekuensi')
pit.title('Distribusi Jumlah Pinjaman')
pit.show()

# %%
data['jenis_kelamin'].value_counts().plot.pie(autopct='%1.0f%%', ylabel='Jenis Kelamin')
# Out:
# <Axes: ylabel='Jenis Kelamin'>

# %%
data['status kredit'].value_counts().plot.pie(
	autopct='%1.0f%%',
	ylabel='Status Kredit'
)
# Out:
# <Axes: ylabel='Status Kredit'>

# %%
import matplotlib.pyplot as plt

data.groupby('tahun_pinjam')['jml_pinjaman'].mean().plot(kind='line')
plt.xlabel('Tahun Pinjam')
plt.ylabel('Rata-rata Jumlah Pinjaman')
plt.title('Rata-rata Jumlah Pinjaman per Tahun Pinjam')
plt.show()
