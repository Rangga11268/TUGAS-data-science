# %%
import pandas as pd
data=pd.read_csv("creditapproval1.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   nama_nasabah            100 non-null    object
#  1   jenis_kelamin           100 non-null    object
#  2   umur                    100 non-null    int64
#  3   jml_pinjaman            100 non-null    float64
#  4   jkw                     100 non-null    int64
#  5   jml_angsuran_per_bulan  100 non-null    float64
#  6   type_pinjaman           100 non-null    int64
#  7   jenis_pinjaman          100 non-null    int64
#  8   bi_sektor_ekonomi       100 non-null    int64
#  9   col                     100 non-null    int64
#  10  bi_golongan_debitur     100 non-null    int64
#  11  bi_gol_penjamin         100 non-null    int64
#  12  saldo_nominatif         100 non-null    float64
#  13  tunggakan_pokok         100 non-null    float64
# ...

# %%
data.nunique()
# Out:
# nama_nasabah              100
# jenis_kelamin               2
# umur                       33
# jml_pinjaman               33
# jkw                        20
# jml_angsuran_per_bulan     61
# type_pinjaman               1
# jenis_pinjaman              5
# bi_sektor_ekonomi           2
# col                         4
# bi_golongan_debitur         2
# bi_gol_penjamin             4
# saldo_nominatif            70
# tunggakan_pokok            57
# tunggakan_bunga            27
# status kredit               2
# dtype: int64

# %%
import numpy as np

np.random.seed(0)
data['tahun_pinjam'] = np.random.choice(range(2018, 2024), size=len(data))
data['tanggal_pinjam'] = [
    pd.Timestamp(f"{tahun}") + pd.to_timedelta(np.random.randint(0, 365), unit='D')
    for tahun in data['tahun_pinjam']
]
data.head()
# Out:
#   nama_nasabah jenis_kelamin  umur  jml_pinjaman  jkw  jml_angsuran_per_bulan  \
# 0         x767             P    36     439000.01    6                95300.01
# 1         x768             P    42     783333.34    9                95370.37
# 2         x769             P    34    5000000.00   24               245833.41
# 3         x770             L    32    1000000.00   12                90833.37
# 4         x771             P    34    2000000.00   12               181666.74
#
#    type_pinjaman  jenis_pinjaman  bi_sektor_ekonomi  col  bi_golongan_debitur  \
# 0            100             301               6000    2                  874
# 1            100             301               6000    2                  874
# 2            100             301               6000    2                  874
# 3            100             301               6000    2                  874
# 4            100             301               6000    2                  874
#
# ...

# %%
data['jenis_kelamin'].value_counts().plot.bar(color=['red', 'blue'])
pit.xlabel('Jenis Kelamin')
pit.ylabel('Jumlah Nasabah')
pit.title('Jumlah Nasabah per Jenis Kelamin')
pit.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import matplotlib.pyplot as plt
#       3 # Visualisasikan mode untuk setiap kolom numerik
# ----> 4 mode_values = data.mode().iloc[0]
#       5 mode_values_numeric = mode_values.select_dtypes(include=np.number)
#       7 mode_values_numeric.plot(kind='bar')
#
# NameError: name 'data' is not defined

# %%
data['Gender'] = data['jenis_kelamin'].str.split().str.get(0)
data['Detail'] = (
    data['jenis_kelamin'].str.split().str.get(1).fillna(' ') + " " +
    data['jenis_kelamin'].str.split().str.get(2).fillna(' ')
).str.strip()
print(data[['jenis_kelamin', 'Gender', 'Detail']].head())

# %%
desc = data[numeric_cols].describe()
desc_var = desc.loc[:, desc.loc['std'] > 0]

print(desc_var)

stats_to_plot = ['mean', 'std', 'min', 'max']
desc_var.loc[stats_to_plot].T.plot(
    kind='bar',
    figsize=(12, 6),
    color=['skyblue', 'orange', 'lightgreen', 'tomato']
)
plt.ylabel('Value')
plt.title('Statistik Deskriptif Kolom Numerik (Non-Konstan)')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Statistik')
plt.tight_layout()
plt.show()

# %%
data['jml_pinjaman'].plot(kind='hist', bins=15, color='skyblue', edgecolor='black')
pit.xlabel('Jumlah Pinjaman')
pit.ylabel('Frekuensi')
pit.title('Distribusi Jumlah Pinjaman Nasabah')
pit.show()
